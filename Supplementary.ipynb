# %% [markdown]
# <a href="https://colab.research.google.com/github/Justin-Bjorn-Sanchez/CPE-311/blob/main/Supplementary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Given the following data structures:
#
# sales = [100,130,119,92,35]
#
# customer_account = ['B100','J101','X102','P103','R104']
#
# city = ['BOS','LA','NYC','SF','CHI']
#
# Create a DataFrame with the data above
# ![image.png](data:image/png;base64,...)
#
# What is the name of the first column?
#
# - **Sales**
#
# Sort the DataFrame by city in descending order (check the documentation for
# sort)
# ![image.png](data:image/png;base64,...)
# Which customer is in the last row of the DataFrame?
#
# - **Customer with Customer Account B100 was in the last row of Dataframe or Customer 0**
#
# Reorder the columns with customer in the first column
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

df = pd.DataFrame({'Sales':[100,130,119,92,35],'Customer Account':['B100','J101','X102','P103','R104'],'City':['BOS','LA','NYC','SF','CHI']})

df.sort_values('City',inplace=True, ascending=False)
df
# Out:
#    Sales Customer Account City
# 3     92             P103   SF
# 2    119             X102  NYC
# 1    130             J101   LA
# 4     35             R104  CHI
# 0    100             B100  BOS

# %% [markdown]
# 2. Load the Titanic Datasetand answer the following questions:
#
#
#
#
#
# What was the average age of the survivors?
#
# ![image.png](data:image/png;base64,...)
#
#
# -**np.float64(29.69911764705882)**
#
#
# What was the combined survival rate of both children (age less than 18) and seniors (age greater than 60)?
#
# ![image.png](data:image/png;base64,...)
#
# -**np.float64(0.3879781420765027)**
#
# Group by pClass and investigate average survival rate, age and fare
#
# ![image.png](data:image/png;base64,...)
#
#
# Create a CSV with the names and ages of the survivors and another CSV file with the names and ages of the deceased.
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# For your submission, attach a screenshot of each code answer (including other required files/outputs). Submit a link to the notebook in the comment section.

# %%
import pandas as pd

df = pd.read_csv('/content/Titanic-Dataset.csv')

survivors = df[df.Survived == 1]
survivors[['Name','Age']].to_csv('Survivors.csv')

deceased = df[df.Survived == 0]
deceased =[['Name','Age']].to_csv('Deceased.csv')
